# %%
import re

import pandas as pd

# %%
raw_data = pd.read_json("scraper/apts.json")
raw_data
# Out:
#              property_name                    address state  zip_code   price  \
# 0            The Berkshire  4201 Massachusetts Ave NW    DC     20016  1634.0
# 1            The Berkshire  4201 Massachusetts Ave NW    DC     20016  1696.0
# 2            The Berkshire  4201 Massachusetts Ave NW    DC     20016  1717.0
# 3            The Berkshire  4201 Massachusetts Ave NW    DC     20016  1634.0
# 4            The Berkshire  4201 Massachusetts Ave NW    DC     20016  1649.0
# ...                    ...                        ...   ...       ...     ...
# 18347  The Hecht Warehouse       1401 New York Ave NE    DC     20002  2436.0
# 18348  The Hecht Warehouse       1401 New York Ave NE    DC     20002  2451.0
# 18349  The Hecht Warehouse       1401 New York Ave NE    DC     20002  2501.0
# 18350  The Hecht Warehouse       1401 New York Ave NE    DC     20002  2741.0
# 18351  The Hecht Warehouse       1401 New York Ave NE    DC     20002  3413.0
#
#        bedrooms  bathrooms square_feet       neighborhood  walk_score  ...  \
# 0             0        1.0         400  Cathedral Heights          71  ...
# 1             0        1.0         400  Cathedral Heights          71  ...
# 2             0        1.0         400  Cathedral Heights          71  ...
# 3             0        1.0         400  Cathedral Heights          71  ...
# 4             0        1.0         400  Cathedral Heights          71  ...
# ...         ...        ...         ...                ...         ...  ...
# 18347         2        2.0         811           Ivy City          80  ...
# 18348         2        2.0         983           Ivy City          80  ...
# 18349         2        2.0         983           Ivy City          80  ...
# 18350         2        2.0        1131           Ivy City          80  ...
# 18351         3        3.0        1337           Ivy City          80  ...
#
#        bike_score                                        description rating  \
# 0              42  The Berkshire embodies the timeless art of liv...    3.9
# 1              42  The Berkshire embodies the timeless art of liv...    3.9
# 2              42  The Berkshire embodies the timeless art of liv...    3.9
# 3              42  The Berkshire embodies the timeless art of liv...    3.9
# 4              42  The Berkshire embodies the timeless art of liv...    3.9
# ...           ...                                                ...    ...
# 18347          64  Introducing a community that’s truly one of a ...    4.7
# 18348          64  Introducing a community that’s truly one of a ...    4.7
# 18349          64  Introducing a community that’s truly one of a ...    4.7
# 18350          64  Introducing a community that’s truly one of a ...    4.7
# 18351          64  Introducing a community that’s truly one of a ...    4.7
#
#        build_year  application_fee  admin_fee  \
# 0            1950             85.0      500.0
# 1            1950             85.0      500.0
# 2            1950             85.0      500.0
# 3            1950             85.0      500.0
# 4            1950             85.0      500.0
# ...           ...              ...        ...
# 18347        1937             75.0      200.0
# 18348        1937             75.0      200.0
# 18349        1937             75.0      200.0
# 18350        1937             75.0      200.0
# 18351        1937             75.0      200.0
#
#                                                  parking  model       unit  \
# 0      [{'title': 'Surface Lot', 'cost': None, 'descr...  EFFMR  Unit 1025
# 1      [{'title': 'Surface Lot', 'cost': None, 'descr...  EFFMR  Unit 4091
# 2      [{'title': 'Surface Lot', 'cost': None, 'descr...  EFFMR  Unit 6044
# 3      [{'title': 'Surface Lot', 'cost': None, 'descr...  EFFMR  Unit 3086
# 4      [{'title': 'Surface Lot', 'cost': None, 'descr...  EFFMR  Unit A324
# ...                                                  ...    ...        ...
# 18347  [{'title': 'Garage', 'cost': '$125 - $150', 'd...     2M   Unit 626
# 18348  [{'title': 'Garage', 'cost': '$125 - $150', 'd...     2A   Unit 325
# 18349  [{'title': 'Garage', 'cost': '$125 - $150', 'd...     2A   Unit 549
# 18350  [{'title': 'Garage', 'cost': '$125 - $150', 'd...     2G   Unit 609
# 18351  [{'title': 'Garage', 'cost': '$125 - $150', 'd...     3F   Unit 701
#
#       available
# 0           Now
# 1           Now
# 2           Now
# 3       Mar. 13
# 4       Mar. 13
# ...         ...
# 18347    Apr. 1
# 18348    Apr. 8
# 18349    Apr. 8
# 18350     May 6
# 18351    Mar. 9
#
# [18352 rows x 21 columns]

# %%
data = raw_data.drop_duplicates(subset=['property_name', 'address', 'state', 'model', 'unit', 'price', 'square_feet']).reset_index(drop=True)
print(f"Total: {len(raw_data)}")
print(f"Unique: {len(data)}")
# Out:
# Total: 18352
# Unique: 9164

# %%
def extract_parking_stats(parking_options: list) -> dict:
    parking_titles = set()
    parking_costs = list()
    for option in parking_options:
        parking_titles.add(option["title"].title())
        cost = option["cost"]
        if cost:
            if "-" in cost:
                cost = cost.split("-")[-1]
            cost = int(re.sub('\D', '', str(cost)))
            parking_costs.append(cost)
    return {
        "has_parking": len(parking_titles - {"Other", "Street"}) > 0,
        "has_garage_parking": "Garage" in parking_titles,
        "cost": min(parking_costs) if len(parking_costs) > 0 else None
    }

# %%
data = data.join(data["parking"].apply(extract_parking_stats).pipe(pd.json_normalize)).drop(columns=["parking"])
data.head()
# Out:
#    property_name                    address state  zip_code   price  bedrooms  \
# 0  The Berkshire  4201 Massachusetts Ave NW    DC     20016  1634.0         0
# 1  The Berkshire  4201 Massachusetts Ave NW    DC     20016  1696.0         0
# 2  The Berkshire  4201 Massachusetts Ave NW    DC     20016  1717.0         0
# 3  The Berkshire  4201 Massachusetts Ave NW    DC     20016  1634.0         0
# 4  The Berkshire  4201 Massachusetts Ave NW    DC     20016  1649.0         0
#
#    bathrooms square_feet       neighborhood  walk_score  ...  rating  \
# 0        1.0         400  Cathedral Heights          71  ...     3.9
# 1        1.0         400  Cathedral Heights          71  ...     3.9
# 2        1.0         400  Cathedral Heights          71  ...     3.9
# 3        1.0         400  Cathedral Heights          71  ...     3.9
# 4        1.0         400  Cathedral Heights          71  ...     3.9
#
#    build_year application_fee  admin_fee  model       unit  available  \
# 0        1950            85.0      500.0  EFFMR  Unit 1025        Now
# 1        1950            85.0      500.0  EFFMR  Unit 4091        Now
# 2        1950            85.0      500.0  EFFMR  Unit 6044        Now
# 3        1950            85.0      500.0  EFFMR  Unit 3086    Mar. 13
# 4        1950            85.0      500.0  EFFMR  Unit A324    Mar. 13
#
#   has_parking has_garage_parking   cost
# 0        True               True  185.0
# 1        True               True  185.0
# 2        True               True  185.0
# 3        True               True  185.0
# 4        True               True  185.0
#
# [5 rows x 23 columns]

# %%
data = data[~data["price"].isna()].reset_index(drop=True)
data["square_feet"] = data["square_feet"].replace({"": None}).astype("Int64")

# %% [markdown]
# ## Analysis

# %%
data.groupby("neighborhood").size().sort_values()
# Out:
# neighborhood
# Lake Barcroft                 4
# Waverly Hills                 5
# Georgetown/Wisconsin Ave      5
# Arlington Heights             6
# Downtown DC                   7
#                            ...
# National Landing            412
# Capitol Riverfront          428
# Union Market                451
# NoMa                        795
# Alexandria West             928
# Length: 88, dtype: int64

# %%
data.groupby("neighborhood")["price"].agg("mean").sort_values()
# Out:
# neighborhood
# Arlandria                   1499.065217
# Oxon Hill                   1540.692308
# Georgetown/Wisconsin Ave    1705.000000
# Beverly Hills               1761.916667
# Huntington                  1819.311828
#                                ...
# The Wharf                   3689.857143
# Cathedral Heights           3915.160377
# Woodley Park                4256.642857
# Navy Yard                   4624.750000
# Eastern Market              5787.692308
# Name: price, Length: 88, dtype: float64

# %%
data["price_per_foot"] = data["price"].div(data["square_feet"])
data.groupby("neighborhood")["price_per_foot"].agg("mean").sort_values()
# Out:
# neighborhood
# Oxon Hill                     1.705912
# Brookville/Seminary Valley    1.746344
# Lincolnia                     1.926686
# Seminary Hill                 2.121428
# Cheverly                      2.125179
#                                 ...
# Eastern Market                4.471556
# U Street                      4.567474
# The Wharf                     4.596896
# West End                      4.608898
# Dupont Circle                 10.64597
# Name: price_per_foot, Length: 88, dtype: Float64

# %%
raw_data[raw_data["address"].str.contains("1425 21st St")]
# Out:
# Empty DataFrame
# Columns: [property_name, address, state, zip_code, price, bedrooms, bathrooms, square_feet, neighborhood, walk_score, transit_score, bike_score, description, rating, build_year, application_fee, admin_fee, parking, model, unit, available]
# Index: []
#
# [0 rows x 21 columns]

# %%
data[data["neighborhood"] == "Dupont Circle"]
# Out:
#             property_name            address state  zip_code   price  \
# 1406  Westpark Apartments       2130 P St NW    DC     20037  2140.0
# 1429  Westpark Apartments       2130 P St NW    DC     20037  2287.0
# 1430  Westpark Apartments       2130 P St NW    DC     20037  2443.0
# 1431  Westpark Apartments       2130 P St NW    DC     20037  2357.0
# 1432  Westpark Apartments       2130 P St NW    DC     20037  2351.0
# 1433  Westpark Apartments       2130 P St NW    DC     20037  2438.0
# 1434  Westpark Apartments       2130 P St NW    DC     20037  2828.0
# 1435  Westpark Apartments       2130 P St NW    DC     20037  2889.0
# 1436  Westpark Apartments       2130 P St NW    DC     20037  2897.0
# 1437  Westpark Apartments       2130 P St NW    DC     20037  2859.0
# 1438  Westpark Apartments       2130 P St NW    DC     20037  2991.0
# 1439  Westpark Apartments       2130 P St NW    DC     20037  2768.0
# 2976       Common Parkway  2147-2149 P St NW    DC     20037  1369.0
# 2977       Common Parkway  2147-2149 P St NW    DC     20037  1542.0
# 2978       Common Parkway  2147-2149 P St NW    DC     20037  1629.0
# 2979       Common Parkway  2147-2149 P St NW    DC     20037  1375.0
# 2980       Common Parkway  2147-2149 P St NW    DC     20037  1396.0
# 2981       Common Parkway  2147-2149 P St NW    DC     20037  1619.0
# 2982       Common Parkway  2147-2149 P St NW    DC     20037  1660.0
# 2983       Common Parkway  2147-2149 P St NW    DC     20037  1375.0
# 2984       Common Parkway  2147-2149 P St NW    DC     20037  1506.0
# 2985       Common Parkway  2147-2149 P St NW    DC     20037  1523.0
# 2986       Common Parkway  2147-2149 P St NW    DC     20037  1669.0
#
#       bedrooms  bathrooms  square_feet   neighborhood  walk_score  ...  \
# 1406         0        1.0          450  Dupont Circle          98  ...
# 1429         0        1.0          470  Dupont Circle          98  ...
# 1430         0        1.0          470  Dupont Circle          98  ...
# 1431         0        1.0          450  Dupont Circle          98  ...
# 1432         0        1.0          450  Dupont Circle          98  ...
# 1433         0        1.0          450  Dupont Circle          98  ...
# 1434         1        1.0          670  Dupont Circle          98  ...
# 1435         1        1.0          670  Dupont Circle          98  ...
# 1436         1        1.0          670  Dupont Circle          98  ...
# 1437         1        1.0          670  Dupont Circle          98  ...
# 1438         1        1.0          710  Dupont Circle          98  ...
# 1439         1        1.0          670  Dupont Circle          98  ...
# 2976         0        1.0           77  Dupont Circle          98  ...
# 2977         0        1.0           99  Dupont Circle          98  ...
# 2978         0        1.0          105  Dupont Circle          98  ...
# 2979         0        1.0           83  Dupont Circle          98  ...
# 2980         0        1.0           85  Dupont Circle          98  ...
# 2981         0        1.0          112  Dupont Circle          98  ...
# 2982         0        1.0           92  Dupont Circle          98  ...
# 2983         0        1.0           80  Dupont Circle          98  ...
# 2984         0        1.0           75  Dupont Circle          98  ...
# 2985         0        1.0           94  Dupont Circle          98  ...
# 2986         0        1.0           80  Dupont Circle          98  ...
#
#       build_year  application_fee admin_fee               model        unit  \
# 1406        1975             50.0     600.0            Studio 2  Unit 00704
# 1429        1975             50.0     600.0            Studio 4  Unit 00426
# 1430        1975             50.0     600.0            Studio 4  Unit 01026
# 1431        1975             50.0     600.0              Studio  Unit 00217
# 1432        1975             50.0     600.0              Studio  Unit 00821
# 1433        1975             50.0     600.0              Studio  Unit 01021
# 1434        1975             50.0     600.0  1 Bed 1 Bath _670A  Unit 00520
# 1435        1975             50.0     600.0  1 Bed 1 Bath _670A  Unit 00820
# 1436        1975             50.0     600.0  1 Bed 1 Bath _670A  Unit 00920
# 1437        1975             50.0     600.0  1 Bed 1 Bath _670A  Unit 01012
# 1438        1975             50.0     600.0   1 Bed 1 Bath_710A  Unit 00827
# 1439        1975             50.0     600.0   1 Bed 1 Bath_670D  Unit 00924
# 2976        2022              NaN       NaN           Suite 302  Unit 302-1
# 2977        2022              NaN       NaN           Suite 302  Unit 302-2
# 2978        2022              NaN       NaN           Suite 302  Unit 302-3
# 2979        2022              NaN       NaN           Suite 502  Unit 502-1
# 2980        2022              NaN       NaN           Suite 502  Unit 502-2
# 2981        2022              NaN       NaN           Suite 502  Unit 502-3
# 2982        2022              NaN       NaN           Suite 502  Unit 502-4
# 2983        2022              NaN       NaN           Suite 203  Unit 203-1
# 2984        2022              NaN       NaN           Suite 203  Unit 203-2
# 2985        2022              NaN       NaN           Suite 402  Unit 402-1
# 2986        2022              NaN       NaN           Suite 402  Unit 402-2
#
#       available  has_parking has_garage_parking   cost price_per_foot
# 1406        Now         True               True  275.0       4.755556
# 1429        Now         True               True  275.0       4.865957
# 1430    Apr. 15         True               True  275.0       5.197872
# 1431        Now         True               True  275.0       5.237778
# 1432    Mar. 15         True               True  275.0       5.224444
# 1433    Mar. 17         True               True  275.0       5.417778
# 1434        Now         True               True  275.0       4.220896
# 1435        Now         True               True  275.0        4.31194
# 1436        Now         True               True  275.0       4.323881
# 1437    Mar. 16         True               True  275.0       4.267164
# 1438        Now         True               True  275.0       4.212676
# 1439     Apr. 6         True               True  275.0       4.131343
# 2976        Now        False              False    NaN      17.779221
# 2977        Now        False              False    NaN      15.575758
# 2978        Now        False              False    NaN      15.514286
# 2979        Now        False              False    NaN      16.566265
# 2980        Now        False              False    NaN      16.423529
# 2981        Now        False              False    NaN      14.455357
# 2982        Now        False              False    NaN      18.043478
# 2983        Now        False              False    NaN        17.1875
# 2984        Now        False              False    NaN          20.08
# 2985        Now        False              False    NaN      16.202128
# 2986        Now        False              False    NaN        20.8625
#
# [23 rows x 24 columns]

# %%
dc_apts = pd.read_json("scraper/apts_dc.json").drop_duplicates(subset=['property_name', 'address', 'state', 'model', 'unit', 'price', 'square_feet'])
len(dc_apts)
# Out:
# 13835

# %%
x = dc_apts[dc_apts["neighborhood"] == "Dupont Circle"]["property_name"].unique()
x
# Out:
# array(['Westpark Apartments', 'The Sedgewick', 'Rocksboro Apartments',
#        'Gables Dupont Circle', '1816 New Hampshire Ave NW Unit 707',
#        '1601 18th St NW Unit 818', '1727 Massachusetts Ave NW Unit 709',
#        '1260 21st St NW Unit Apt 707', 'The Croydon', 'President Madison',
#        'Bristol House', 'Common Parkway'], dtype=object)

# %%
y = pd.read_json("scraper/apts_dupont.json")
y[y["neighborhood"] == "Dupont Circle"]["property_name"].unique()
# Out:
# array(['Westpark Apartments', 'The Croydon', 'President Madison',
#        'Bristol House', '1601 18th St NW Unit 818',
#        '1816 New Hampshire Ave NW Unit 707', 'Gables Dupont Circle',
#        'Rocksboro Apartments', '1727 Massachusetts Ave NW Unit 709',
#        '1415 17th St NW Unit FL2-ID25',
#        'Full bedroom in 4 bed/2 bath Home',
#        'Full bedroom in 5 bed/2 bath Home',
#        '1415 17th St NW Unit FL0-ID62', '2107 O St NW Unit FL1-ID340',
#        '1830 17th St NW Unit 201', '1330 New Hampshire Ave NW Unit 607',
#        '1545 18th St NW Unit 205', '1330 New Hampshire Ave NW Unit 902',
#        '1724 21st St NW', '2130 N St NW Unit 310', '1507 R St NW',
#        '1828 Riggs Pl NW Unit 1', '1301 20th St NW Unit 916',
#        '2025 N St NW', '1325 18th St NW Unit 902',
#        '1425 21st St NW Unit 101', '2029 O St NW',
#        '1750 Corcoran St NW Unit B', '1260 21st St NW Unit 910',
#        '2 br, 2 bath House - 2122 N St NW #3',
#        '1 br, 1 bath House - 2113 O Street Unit 2113B',
#        '2130 N St NW Unit Apt 310', '1758 Swann St NW',
#        '2 br, 2 bath House - 1736 19th St, NW Unit 2',
#        '1 br, 1 bath House - 1322 15th St NW  Unit 2',
#        'Studio, 1 bath House - 1711 Massachusetts ...',
#        '1 br, 1 bath House - 1425 21st Street, NW ...',
#        '1 br, 1 bath House - 1260 21st St, NW Unit...',
#        '1 br, 1 bath House - 1511 22nd St NW  #24',
#        '1 br, 1 bath House - 1325 18th STNW #706',
#        'Studio, 1 bath House - 1601 18th Street, N...',
#        '2122 N St NW Unit 3', '1177 22nd St NW Unit 6M',
#        '2007 O St NW Unit 401', '2113 O St NW Unit 2113B', '1612 T St NW',
#        '1511 22nd St NW Unit 15', '1301 20th St NW Unit 1017',
#        '1745 N St NW Unit 402', '1772 Church St NW Unit FL2-ID288',
# 15403    DC   20037.0  1375.0         0        1.0          83  Dupont Circle
# 15404    DC   20037.0  1396.0         0        1.0          85  Dupont Circle
# 15405    DC   20037.0  1619.0         0        1.0         112  Dupont Circle
# 15406    DC   20037.0  1660.0         0        1.0          92  Dupont Circle
# 15407    DC   20037.0  1375.0         0        1.0          80  Dupont Circle
# 15408    DC   20037.0  1506.0         0        1.0          75  Dupont Circle
# 15409    DC   20037.0  1523.0         0        1.0          94  Dupont Circle
# 15410    DC   20037.0  1669.0         0        1.0          80  Dupont Circle
#
#        walk_score  ...  bike_score  \
# 3939         98.0  ...        95.0
# 3968         98.0  ...        95.0
# 3969         98.0  ...        95.0
# 3970         98.0  ...        95.0
# 3971         98.0  ...        95.0
# 3972         98.0  ...        95.0
# 3973         98.0  ...        95.0
# 3974         98.0  ...        95.0
# 3975         98.0  ...        95.0
# 3976         98.0  ...        95.0
# 3977         98.0  ...        95.0
# 3978         98.0  ...        95.0
# 6959         99.0  ...        99.0
# 6960         99.0  ...        99.0
# 6961         99.0  ...        99.0
# 6962         99.0  ...        99.0
# 6963         99.0  ...        99.0
# 6964         99.0  ...        99.0
# 6965         99.0  ...        99.0
# 6966         99.0  ...        99.0
# 6967         99.0  ...        99.0
# 6968         99.0  ...        99.0
# 7816         98.0  ...        99.0
# 7817         98.0  ...        99.0
# 7818         98.0  ...        99.0
# 7819         98.0  ...        99.0
# 7820         98.0  ...        99.0
# 7821         98.0  ...        99.0
# 7898         99.0  ...        97.0
# 7899         99.0  ...        97.0
# 8383         98.0  ...        99.0
# 8437         99.0  ...        98.0
# 8802         99.0  ...        94.0
# 8815         94.0  ...        92.0
# 8916         98.0  ...        99.0
# 8917         98.0  ...        99.0
# 8977         99.0  ...        99.0
# 8978         99.0  ...        99.0
# 8979         99.0  ...        99.0
# 8983        100.0  ...        95.0
# 8984        100.0  ...        95.0
# 8985        100.0  ...        95.0
# 8986        100.0  ...        95.0
# 15400        98.0  ...        95.0
# 15401        98.0  ...        95.0
# 15402        98.0  ...        95.0
# 15403        98.0  ...        95.0
# 15404        98.0  ...        95.0
# 15405        98.0  ...        95.0
# 15406        98.0  ...        95.0
# 15407        98.0  ...        95.0
# 15408        98.0  ...        95.0
# 15409        98.0  ...        95.0
# 15410        98.0  ...        95.0
#
#                                              description rating  build_year  \
# 3939   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3968   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3969   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3970   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3971   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3972   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3973   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3974   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3975   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3976   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3977   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 3978   Come home to Westpark Apartments, where timele...    4.0      1975.0
# 6959   The Sedgewick provides elegantly designed home...    4.0      1929.0
# 6960   The Sedgewick provides elegantly designed home...    4.0      1929.0
# 6961   The Sedgewick provides elegantly designed home...    4.0      1929.0
# 6962   The Sedgewick provides elegantly designed home...    4.0      1929.0
# 6963   The Sedgewick provides elegantly designed home...    4.0      1929.0
# 6964   The Sedgewick provides elegantly designed home...    4.0      1929.0
# 6965   The Sedgewick provides elegantly designed home...    4.0      1929.0
# 6966   The Sedgewick provides elegantly designed home...    4.0      1929.0
# 6967   The Sedgewick provides elegantly designed home...    4.0      1929.0
# 6968   The Sedgewick provides elegantly designed home...    4.0      1929.0
# 7816   Boutique living, and extraordinary location on...    3.8      1945.0
# 7817   Boutique living, and extraordinary location on...    3.8      1945.0
# 7818   Boutique living, and extraordinary location on...    3.8      1945.0
# 7819   Boutique living, and extraordinary location on...    3.8      1945.0
# 7820   Boutique living, and extraordinary location on...    3.8      1945.0
# 7821   Boutique living, and extraordinary location on...    3.8      1945.0
# 7898   Nestled on a quiet residential street surround...    5.0      1996.0
# 7899   Nestled on a quiet residential street surround...    5.0      1996.0
# 8383   Welcome to your new home in the Concord, a hig...    NaN         NaN
# 8437   NEWLY AND COMPLETELY RENOVATED gorgeous, sunny...    NaN         NaN
# 8802   Available March 1, 2023. Perfect downtown Tele...    NaN         NaN
# 8815   1260 21st St NW is an apartment community loca...    NaN         NaN
# 8916   Located on 17th Street Corridor and close to D...    4.0      1941.0
# 8917   Located on 17th Street Corridor and close to D...    4.0      1941.0
# 8977   Here we believe in making you feel at home in ...    4.0      1905.0
# 8978   Here we believe in making you feel at home in ...    4.0      1905.0
# 8979   Here we believe in making you feel at home in ...    4.0      1905.0
# 8983   The Bristol House is cosmopolitan DC living at...    4.0      1963.0
# 8984   The Bristol House is cosmopolitan DC living at...    4.0      1963.0
# 8985   The Bristol House is cosmopolitan DC living at...    4.0      1963.0
# 8986   The Bristol House is cosmopolitan DC living at...    4.0      1963.0
# 15400  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
# 15401  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
# 15402  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
# 15403  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
# 15404  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
# 15405  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
# 15406  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
# 15407  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
# 15408  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
# 15409  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
# 15410  Private (unfurnished) rooms in a furnished sha...    4.0      2022.0
#
#        application_fee  admin_fee  \
# 3939              50.0      600.0
# 3968              50.0      600.0
# 3969              50.0      600.0
# 3970              50.0      600.0
# 3971              50.0      600.0
# 3972              50.0      600.0
# 3973              50.0      600.0
# 3974              50.0      600.0
# 3975              50.0      600.0
# 3976              50.0      600.0
# 3977              50.0      600.0
# 3978              50.0      600.0
# 6959              75.0      600.0
# 6960              75.0      600.0
# 6961              75.0      600.0
# 6962              75.0      600.0
# 6963              75.0      600.0
# 6964              75.0      600.0
# 6965              75.0      600.0
# 6966              75.0      600.0
# 6967              75.0      600.0
# 6968              75.0      600.0
# 7816              50.0        NaN
# 7817              50.0        NaN
# 7818              50.0        NaN
# 7819              50.0        NaN
# 7820              50.0        NaN
# 7821              50.0        NaN
# 7898              80.0      600.0
# 7899              80.0      600.0
# 8383               NaN        NaN
# 8437               NaN        NaN
# 8802               NaN        NaN
# 8815               NaN        NaN
# 8916              50.0      300.0
# 8917              50.0      300.0
# 8977              50.0        NaN
# 8978              50.0        NaN
# 8979              50.0        NaN
# 8983              50.0      500.0
# 8984              50.0      500.0
# 8985              50.0      500.0
# 8986              50.0      500.0
# 15400              NaN        NaN
# 15401              NaN        NaN
# 15402              NaN        NaN
# 15403              NaN        NaN
# 15404              NaN        NaN
# 15405              NaN        NaN
# 15406              NaN        NaN
# 15407              NaN        NaN
# 15408              NaN        NaN
# 15409              NaN        NaN
# 15410              NaN        NaN
#
#                                                  parking  \
# 3939   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3968   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3969   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3970   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3971   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3972   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3973   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3974   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3975   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3976   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3977   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 3978   [{'title': 'Surface Lot', 'cost': '$275', 'des...
# 6959   [{'title': 'Surface Lot', 'cost': None, 'descr...
# 6960   [{'title': 'Surface Lot', 'cost': None, 'descr...
# 6961   [{'title': 'Surface Lot', 'cost': None, 'descr...
# 6962   [{'title': 'Surface Lot', 'cost': None, 'descr...
# 6963   [{'title': 'Surface Lot', 'cost': None, 'descr...
# 6964   [{'title': 'Surface Lot', 'cost': None, 'descr...
# 6965   [{'title': 'Surface Lot', 'cost': None, 'descr...
# 6966   [{'title': 'Surface Lot', 'cost': None, 'descr...
# 6967   [{'title': 'Surface Lot', 'cost': None, 'descr...
# 6968   [{'title': 'Surface Lot', 'cost': None, 'descr...
# 7816   [{'title': 'Other', 'cost': None, 'description...
# 7817   [{'title': 'Other', 'cost': None, 'description...
# 7818   [{'title': 'Other', 'cost': None, 'description...
# 7819   [{'title': 'Other', 'cost': None, 'description...
# 7820   [{'title': 'Other', 'cost': None, 'description...
# 7821   [{'title': 'Other', 'cost': None, 'description...
# 7898   [{'title': 'Covered', 'cost': '$250 - $300', '...
# 7899   [{'title': 'Covered', 'cost': '$250 - $300', '...
# 8383                                                  []
# 8437   [{'title': 'Street', 'cost': None, 'descriptio...
# 8802   [{'title': 'Street', 'cost': None, 'descriptio...
# 8815   [{'title': 'Street', 'cost': None, 'descriptio...
# 8916   [{'title': 'Surface Lot', 'cost': '$190', 'des...
# 8917   [{'title': 'Surface Lot', 'cost': '$190', 'des...
# 8977   [{'title': 'Surface Lot', 'cost': '$215', 'des...
# 8978   [{'title': 'Surface Lot', 'cost': '$215', 'des...
# 8979   [{'title': 'Surface Lot', 'cost': '$215', 'des...
# 8983   [{'title': 'Surface Lot', 'cost': '$200', 'des...
# 8984   [{'title': 'Surface Lot', 'cost': '$200', 'des...
# 8985   [{'title': 'Surface Lot', 'cost': '$200', 'des...
# 8986   [{'title': 'Surface Lot', 'cost': '$200', 'des...
# 15400                                                 []
# 15401                                                 []
# 15402                                                 []
# 15403                                                 []
# 15404                                                 []
# 15405                                                 []
# 15406                                                 []
# 15407                                                 []
# 15408                                                 []
# 15409                                                 []
# 15410                                                 []
#
#                               model          unit available
# 3939                       Studio 2    Unit 00704       Now
# 3968                       Studio 4    Unit 00426       Now
# 3969                       Studio 4    Unit 01026   Apr. 15
# 3970                         Studio    Unit 00217       Now
# 3971                         Studio    Unit 00821   Mar. 15
# 3972                         Studio    Unit 01021   Mar. 17
# 3973             1 Bed 1 Bath _670A    Unit 00820       Now
# 3974             1 Bed 1 Bath _670A    Unit 00520       Now
# 3975             1 Bed 1 Bath _670A    Unit 00920       Now
# 3976             1 Bed 1 Bath _670A    Unit 01012   Mar. 16
# 3977              1 Bed 1 Bath_710A    Unit 00827       Now
# 3978              1 Bed 1 Bath_670D    Unit 00924    Apr. 6
# 6959   Renovated Efficiency 08 Tier      Unit 308      Soon
# 6960              1 Bedroom 01 Tier      Unit 401      Soon
# 6961              1 Bedroom 01 Tier      Unit 201      Soon
# 6962              1 Bedroom 01 Tier      Unit 301      Soon
# 6963              1 Bedroom 05 Tier      Unit 305      Soon
# 6964              1 Bedroom 05 Tier      Unit 605      Soon
# 6965              1 Bedroom 05 Tier      Unit 505      Soon
# 6966    Renovated 1 Bedroom 11 Tier      Unit 311      Soon
# 6967              2 Bedroom 02 Tier      Unit 202      Soon
# 6968              2 Bedroom 03 Tier      Unit 803      Soon
# 7816             Efficiency 14 Tier      Unit 514       Now
# 7817             Efficiency 05 Tier      Unit 505       Now
# 7818             Efficiency 07 Tier      Unit 407       Now
# 7819             Efficiency 13 Tier      Unit 313       Now
# 7820             Efficiency 10 Tier      Unit 510   Mar. 17
# 7821             Efficiency 08 Tier      Unit 108   Apr. 18
# 7898                             B1     Unit 0604    Apr. 8
# 7899                            BTH      Unit TH4   Apr. 19
# 8383                            NaN           NaN       NaN
# 8437                            NaN           NaN       NaN
# 8802                            NaN           NaN       NaN
# 8815                            NaN           NaN       NaN
# 8916               Studio - Tier 15  Unit 001-315   Mar. 31
# 8917           Studio - Tiers 6 & 7  Unit 001-706   Mar. 31
# 8977                         Studio      Unit 126       Now
# 8978                         Studio      Unit 107       Now
# 8979                    One Bedroom      Unit 105     May 1
# 8983      Studio1BATH Tier5-7,12-19  Unit 001-314       Now
# 8984      Studio 1BATH Tier 09 & 11  Unit 001-209    May 31
# 8985       1BED 1BATH Tier 03-08-10  Unit 001-510   Mar. 31
# 8986                2BED 2BATH #901  Unit 001-901   Mar. 31
# 15400                     Suite 302    Unit 302-1   Mar. 10
# 15401                     Suite 302    Unit 302-2   Mar. 10
# 15402                     Suite 302    Unit 302-3   Mar. 10
# 15403                     Suite 502    Unit 502-1   Mar. 10
# 15404                     Suite 502    Unit 502-2   Mar. 10
# 15405                     Suite 502    Unit 502-3   Mar. 10
# 15406                     Suite 502    Unit 502-4   Mar. 10
# 15407                     Suite 203    Unit 203-1   Mar. 10
# 15408                     Suite 203    Unit 203-2   Mar. 10
# 15409                     Suite 402    Unit 402-1   Mar. 10
# 15410                     Suite 402    Unit 402-2   Mar. 10
#
# [54 rows x 21 columns]

# %%
cost = "$125 - $150".split("-")[-1]
int(re.sub('\D', '', str(cost)))
# Out:
# 150

# %%
p = data["parking"].apply(extract_parking_stats).pipe(pd.json_normalize)
p[p["cost"] > 500]
# Out:
# Empty DataFrame
# Columns: [has_parking, has_garage_parking, cost]
# Index: []

# %%
data["parking"].loc[6330]
# Out:
# [{'title': 'Garage',
#   'cost': '$400 - $500',
#   'description': '1 space, Assigned Parking'}]

# %%
x = raw_data.drop(columns='parking').drop_duplicates()
x[x.duplicated(subset=['property_name', 'address', 'state', 'model', 'unit'], keep=False)]
# Out:
#                      property_name           address state  zip_code   price  \
# 2236                    South Port    6112 Edsall Rd    VA     22304  1802.0
# 2237                    South Port    6112 Edsall Rd    VA     22304  1462.0
# 2241                    South Port    6112 Edsall Rd    VA     22304  1557.0
# 2242                    South Port    6112 Edsall Rd    VA     22304  1557.0
# 2249                    South Port    6112 Edsall Rd    VA     22304  2299.0
# 2250                    South Port    6112 Edsall Rd    VA     22304  2599.0
# 5631       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1475.0
# 5632       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1560.0
# 5633       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1565.0
# 5634       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1525.0
# 5636       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1530.0
# 5637       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1570.0
# 5638       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1580.0
# 5639       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1445.0
# 5640       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1520.0
# 5641       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1700.0
# 5643       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1760.0
# 5644       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1795.0
# 5645       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1810.0
# 5646       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1825.0
# 5647       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1760.0
# 5648       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1710.0
# 5649       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1750.0
# 5650       Braddock Lee Apartments   2423 Menokin Dr    VA     22302  1810.0
# 6940        Courts Of Mount Vernon     3601 Albee Ln    VA     22309  2825.0
# 6941        Courts Of Mount Vernon     3601 Albee Ln    VA     22309  2080.0
# 9164   Park Shirlington Apartments    4510 S 31st St    VA     22206  1679.0
# 9167   Park Shirlington Apartments    4510 S 31st St    VA     22206  1679.0
# 9168   Park Shirlington Apartments    4510 S 31st St    VA     22206  1714.0
# 9171   Park Shirlington Apartments    4510 S 31st St    VA     22206  1714.0
# 11014         Sussex at Kingstowne  6050 Edgeware Ln    VA     22315  2050.0
# 11016         Sussex at Kingstowne  6050 Edgeware Ln    VA     22315  2050.0
# 11020         Sussex at Kingstowne  6050 Edgeware Ln    VA     22315  2085.0
# 11022         Sussex at Kingstowne  6050 Edgeware Ln    VA     22315  2075.0
# 11023         Sussex at Kingstowne  6050 Edgeware Ln    VA     22315  2305.0
# 11024         Sussex at Kingstowne  6050 Edgeware Ln    VA     22315  2370.0
# 11025         Sussex at Kingstowne  6050 Edgeware Ln    VA     22315  2340.0
#
#        bedrooms  bathrooms square_feet             neighborhood  walk_score  \
# 2236          1        1.0         717        Landmark/Van Dorn          70
# 2237          1        1.0         717        Landmark/Van Dorn          70
# 2241          1        1.0         889        Landmark/Van Dorn          70
# 2242          1        1.0         889        Landmark/Van Dorn          70
# 2249          3        2.0        1157        Landmark/Van Dorn          70
# 2250          3        2.0        1157        Landmark/Van Dorn          70
# 5631          1        1.0         660            Seminary Hill          52
# 5632          1        1.0         660            Seminary Hill          52
# 5633          1        1.0         660            Seminary Hill          52
# 5634          1        1.0         660            Seminary Hill          52
# 5636          1        1.0         660            Seminary Hill          52
# 5637          1        1.0         660            Seminary Hill          52
# 5638          1        1.0         660            Seminary Hill          52
# 5639          1        1.0         660            Seminary Hill          52
# 5640          1        1.0         660            Seminary Hill          52
# 5641          2        1.0         930            Seminary Hill          52
# 5643          2        1.0         930            Seminary Hill          52
# 5644          2        1.0         930            Seminary Hill          52
# 5645          2        1.0         930            Seminary Hill          52
# 5646          2        1.0         930            Seminary Hill          52
# 5647          2        1.0         930            Seminary Hill          52
# 5648          2        1.0         930            Seminary Hill          52
# 5649          2        1.0         930            Seminary Hill          52
# 5650          2        1.0         930            Seminary Hill          52
# 6940          2        1.5         900             Mount Vernon          70
# 6941          2        1.5         900             Mount Vernon          70
# 9164          2        1.0         755  Fairlington/Shirlington          69
# 9167          2        1.0         755  Fairlington/Shirlington          69
# 9168          2        1.0         825  Fairlington/Shirlington          69
# 9171          2        1.0         825  Fairlington/Shirlington          69
# 11014         1        1.0         821                Franconia          61
# 11016         1        1.0         821                Franconia          61
# 11020         1        1.0         948                Franconia          61
# 11022         1        1.0         948                Franconia          61
# 11023         1        2.0        1056                Franconia          61
# 11024         1        2.0        1056                Franconia          61
# 11025         1        2.0        1056                Franconia          61
#
#        transit_score  bike_score  \
# 2236              58          28
# 2237              58          28
# 2241              58          28
# 2242              58          28
# 2249              58          28
# 2250              58          28
# 5631              58          61
# 5632              58          61
# 5633              58          61
# 5634              58          61
# 5636              58          61
# 5637              58          61
# 5638              58          61
# 5639              58          61
# 5640              58          61
# 5641              58          61
# 5643              58          61
# 5644              58          61
# 5645              58          61
# 5646              58          61
# 5647              58          61
# 5648              58          61
# 5649              58          61
# 5650              58          61
# 6940               0          39
# 6941               0          39
# 9164              60          59
# 9167              60          59
# 9168              60          59
# 9171              60          59
# 11014              0          65
# 11016              0          65
# 11020              0          65
# 11022              0          65
# 11023              0          65
# 11024              0          65
# 11025              0          65
#
#                                              description  rating  build_year  \
# 2236   South Port is nestled on 22 acres near the cor...     3.9        1966
# 2237   South Port is nestled on 22 acres near the cor...     3.9        1966
# 2241   South Port is nestled on 22 acres near the cor...     3.9        1966
# 2242   South Port is nestled on 22 acres near the cor...     3.9        1966
# 2249   South Port is nestled on 22 acres near the cor...     3.9        1966
# 2250   South Port is nestled on 22 acres near the cor...     3.9        1966
# 5631   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5632   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5633   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5634   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5636   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5637   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5638   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5639   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5640   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5641   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5643   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5644   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5645   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5646   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5647   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5648   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
# 5649   Located in Alexandria, Virginia, Braddock Lee ...     3.8        1955
#